# %% [markdown]
# List To DataFrame

# %%
import pandas as pd

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info() # to shows the column and rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
city=["Dhaka","Faridpur"]
df=pd.DataFrame(city)
print(df)
# Out:
#           0
# 0     Dhaka
# 1  Faridpur

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
# dtypes: object(1)
# memory usage: 144.0+ bytes

# %%
print(type(city))
type(df)
# Out:
# <class 'list'>
# pandas.core.frame.DataFrame

# %%
city=["Dhaka","Faridpur","B-Baria"]
df=pd.DataFrame(city,columns=["city in Bangladesh"],index=['c1','c2','c3']) #column names are set by columns and row name is set by indes 
print(df)
# Out:
#    city in Bangladesh
# c1              Dhaka
# c2           Faridpur
# c3            B-Baria

# %%
city2=["NY","LA","California"]
df2=pd.DataFrame(zip(city,city2),columns=["city1","city2"],index=["tear-1","tear-2","tear-3"]) #aggrigate two list here 
print(df2)
# Out:
#            city1       city2
# tear-1     Dhaka          NY
# tear-2  Faridpur          LA
# tear-3   B-Baria  California

# %%
print(df2.shape)
df.shape
# Out:
# (3, 2)
# (3, 1)

# %% [markdown]
# 2D List

# %%
city_location=[["dhaka","faridpur","B-Baria"],["Gulshan","Boalmari","Unknown"]]
df3=pd.DataFrame(city_location,columns=["capital","city1","city2"],index=["main city","upozila"])
print(df3)
# Out:
#            capital     city1    city2
# main city    dhaka  faridpur  B-Baria
# upozila    Gulshan  Boalmari  Unknown

# %%
dict={
    'city':city,
    'city2':city2,
    'city3':city_location
}
print(dict)
# Out:
# {'city': ['Dhaka', 'Faridpur', 'B-Baria'], 'city2': ['NY', 'LA', 'California'], 'city3': [['dhaka', 'faridpur', 'B-Baria'], ['Gulshan', 'Boalmari', 'Unknown']]}

# %%
# Ensure all arrays in the dictionary have the same length
dict = {
	'city': city,
	'city2': city2,
}

df4 = pd.DataFrame(dict)
print(df4)
# Out:
#        city       city2
# 0     Dhaka          NY
# 1  Faridpur          LA
# 2   B-Baria  California

# %%
df5=pd.read_csv("Screen Time Data.csv")# read CSV file
df5
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 4       4  04/21/19     Sunday                  56                 35
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 8       8  04/25/19   Thursday                  52                 25
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 11     11  04/28/19     Sunday                  85                 42
# ...

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
df5.head() # shows first 5 rows
# Out:
#    index      Date   Week Day  Total Screen Time   Social Networking  \
# 0      0  04/17/19  Wednesday                 187                 89
# 1      1  04/18/19   Thursday                 123                 78
# 2      2  04/19/19     Friday                 112                 52
# 3      3  04/20/19   Saturday                 101                 69
# 4      4  04/21/19     Sunday                  56                 35
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# 2                     40      8             4                   0
# 3                      9     38             2                   0
# 4                      2     43             3                   0
#
#    Entertainment  Creativity  Yoga
# 0              0           0     0
# 1              0           0     0
# 2              3           0     0
# ...

# %%
df5.tail() # shows last 5 rows
# Out:
#     index      Date  Week Day  Total Screen Time   Social Networking  \
# 23     23  05/10/19    Friday                 161                 93
# 24     24  05/11/19  Saturday                  58                 49
# 25     25  05/12/19    Sunday                  52                 28
# 26     26  05/13/19    Monday                  61                 37
# 27     27  05/14/19   Tuesday                  88                 41
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 23                     13     17            16                   1
# 24                      1      2             2                   0
# 25                      1      1             6                   0
# 26                      1      0             4                   0
# 27                      2      7            15                   0
#
#     Entertainment  Creativity  Yoga
# 23              0           0     1
# 24              0           2     1
# ...

# %%
df5.head(10) # shows first 10 rows
df5.tail(10) # shows last 10 columns
print(df5.values) # shows the values inside df5
print(df5.columns) # shows df5 column names
print(df5.index) # shows df5 rows names
# Out:
# [[0 '04/17/19' 'Wednesday' 187 89 17 41 22 0 0 0 0]
#  [1 '04/18/19' 'Thursday' 123 78 17 8 9 0 0 0 0]
#  [2 '04/19/19' 'Friday' 112 52 40 8 4 0 3 0 0]
#  [3 '04/20/19' 'Saturday' 101 69 9 38 2 0 3 0 0]
#  [4 '04/21/19' 'Sunday' 56 35 2 43 3 0 1 1 0]
#  [5 '04/22/19' 'Monday' 189 68 0 9 3 4 0 0 0]
#  [6 '04/23/19' 'Tuesday' 158 56 18 41 12 15 0 0 0]
#  [7 '04/24/19' 'Wednesday' 135 98 3 33 16 0 0 0 0]
#  [8 '04/25/19' 'Thursday' 52 25 7 3 16 0 0 0 0]
#  [9 '04/26/19' 'Friday' 198 76 8 29 15 0 32 0 0]
#  [10 '04/27/19' 'Saturday' 116 75 10 20 5 0 0 0 0]
#  [11 '04/28/19' 'Sunday' 85 42 22 4 2 0 0 0 0]
#  [12 '04/29/19' 'Monday' 109 46 8 13 9 15 1 0 1]
#  [13 '04/30/19' 'Tuesday' 79 40 2 9 12 0 0 0 1]
#  [14 '05/01/19' 'Wednesday' 127 90 0 10 7 0 0 0 1]
#  [15 '05/02/19' 'Thursday' 170 60 3 2 11 0 0 0 1]
#  [16 '05/03/19' 'Friday' 91 64 2 18 5 1 1 2 1]
#  [17 '05/04/19' 'Saturday' 58 34 4 5 3 0 1 0 1]
#  [18 '05/05/19' 'Sunday' 133 109 5 1 3 0 0 0 1]
# ...

# %%
a=df5.Date
print(a)
# Out:
# 0     04/17/19
# 1     04/18/19
# 2     04/19/19
# 3     04/20/19
# 4     04/21/19
# 5     04/22/19
# 6     04/23/19
# 7     04/24/19
# 8     04/25/19
# 9     04/26/19
# 10    04/27/19
# 11    04/28/19
# 12    04/29/19
# 13    04/30/19
# 14    05/01/19
# 15    05/02/19
# 16    05/03/19
# 17    05/04/19
# 18    05/05/19
# 19    05/06/19
# 20    05/07/19
# 21    05/08/19
# 22    05/09/19
# 23    05/10/19
# 24    05/11/19
# 25    05/12/19
# 26    05/13/19
# 27    05/14/19
# Name: Date, dtype: object

# %%
df5[['Social Networking']] # if there is space then use this
# Out:
#     Social Networking
# 0                  89
# 1                  78
# 2                  52
# 3                  69
# 4                  35
# 5                  68
# 6                  56
# 7                  98
# 8                  25
# 9                  76
# 10                 75
# 11                 42
# 12                 46
# 13                 40
# 14                 90
# 15                 60
# 16                 64
# 17                 34
# 18                109
# 19                 81
# 20                 70
# 21                 53
# 22                 42
# 23                 93
# 24                 49
# 25                 28
# 26                 37
# 27                 41

# %%
df5.Date.head()
# Out:
# 0    04/17/19
# 1    04/18/19
# 2    04/19/19
# 3    04/20/19
# 4    04/21/19
# Name: Date, dtype: object

# %%
df5[["Date","Social Networking"]].head()
# Out:
#        Date  Social Networking
# 0  04/17/19                 89
# 1  04/18/19                 78
# 2  04/19/19                 52
# 3  04/20/19                 69
# 4  04/21/19                 35

# %%
df5['Social Networking'].head().sort_values()
# Out:
# 4    35
# 2    52
# 3    69
# 1    78
# 0    89
# Name: Social Networking, dtype: int64

# %%
df5['Social Networking'].head().sort_index()
# Out:
# 0    89
# 1    78
# 2    52
# 3    69
# 4    35
# Name: Social Networking, dtype: int64

# %%
df5['Social Networking'].head().sort_values(ascending=False)#high to low sorting
# Out:
# 0    89
# 1    78
# 3    69
# 2    52
# 4    35
# Name: Social Networking, dtype: int64

# %%
df5.sort_values('Social Networking').head() #full dataframe sprting respect to social Networking
# Out:
#     index      Date  Week Day  Total Screen Time   Social Networking  \
# 8       8  04/25/19  Thursday                  52                 25
# 25     25  05/12/19    Sunday                  52                 28
# 17     17  05/04/19  Saturday                  58                 34
# 4       4  04/21/19    Sunday                  56                 35
# 26     26  05/13/19    Monday                  61                 37
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 8                       7      3            16                   0
# 25                      1      1             6                   0
# 17                      4      5             3                   0
# 4                       2     43             3                   0
# 26                      1      0             4                   0
#
#     Entertainment  Creativity  Yoga
# 8               0           0     0
# 25              0           1     1
# ...

# %%
df5.describe() #describe everything in this numerical data
# Out:
#            index  Total Screen Time   Social Networking  \
# count  28.000000           28.000000          28.000000
# mean   13.500000          113.250000          60.714286
# std     8.225975           43.562322          22.853571
# min     0.000000           52.000000          25.000000
# 25%     6.750000           83.500000          41.750000
# 50%    13.500000          111.000000          58.000000
# 75%    20.250000          137.250000          76.500000
# max    27.000000          198.000000         109.000000
#
#        Reading and Reference      Other  Productivity  Health and Fitness  \
# count              28.000000  28.000000     28.000000           28.000000
# mean                8.714286  14.821429      9.071429            1.285714
# std                 9.340700  13.754605      6.097532            3.952094
# min                 0.000000   0.000000      2.000000            0.000000
# 25%                 2.000000   4.750000      3.000000            0.000000
# ...

# %%
df5.select_dtypes(include=['number']).corr()
# Out:
#                           index  Total Screen Time   Social Networking  \
# index                  1.000000           -0.344952          -0.218093
# Total Screen Time     -0.344952            1.000000           0.710864
# Social Networking     -0.218093            0.710864           1.000000
# Reading and Reference -0.360073            0.185685           0.004461
# Other                 -0.537331            0.333433           0.234066
# Productivity           0.012553            0.344195           0.124539
# Health and Fitness    -0.178863            0.201360          -0.092968
# Entertainment         -0.113858            0.343897           0.132916
# Creativity             0.221908           -0.409306          -0.214764
# Yoga                   0.857690           -0.258123          -0.110716
#
#                        Reading and Reference     Other  Productivity  \
# index                              -0.360073 -0.537331      0.012553
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df5.select_dtypes(include=['number']),annot=True)
# Out:
# <Axes: >

# %%
df5[df5['Social Networking']>50]
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 14     14  05/01/19  Wednesday                 127                 90
# 15     15  05/02/19   Thursday                 170                 60
# 16     16  05/03/19     Friday                  91                 64
# ...

# %%
df5[(df5['Week Day'] == 'Wednesday') | (df5['Reading and Reference'] > 10)]
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 11     11  04/28/19     Sunday                  85                 42
# 14     14  05/01/19  Wednesday                 127                 90
# 21     21  05/08/19  Wednesday                 122                 53
# 22     22  05/09/19   Thursday                  96                 42
# 23     23  05/10/19     Friday                 161                 93
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                      17     41            22                   0
# ...

# %%
df5[df5['Week Day'].isin(['Tuesday','Friday'])]
# Out:
#     index      Date Week Day  Total Screen Time   Social Networking  \
# 2       2  04/19/19   Friday                 112                 52
# 6       6  04/23/19  Tuesday                 158                 56
# 9       9  04/26/19   Friday                 198                 76
# 13     13  04/30/19  Tuesday                  79                 40
# 16     16  05/03/19   Friday                  91                 64
# 20     20  05/07/19  Tuesday                 110                 70
# 23     23  05/10/19   Friday                 161                 93
# 27     27  05/14/19  Tuesday                  88                 41
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 2                      40      8             4                   0
# 6                      18     41            12                  15
# 9                       8     29            15                   0
# 13                      2      9            12                   0
# ...
